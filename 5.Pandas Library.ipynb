# %% [markdown]
# # Pandas
# - Pandas is an open-source library that is made mainly for working with relational or labeled data both easily and intuitively.
# - It provides various data structures and operations for manipulating numerical data and time series.
# - This library is built on top of the NumPy library.
# - Pandas is fast and it has high performance & productivity for users.
# - With the help of pandas library we can also perform data visualization.

# %%
#Importing library

# %%
# !pip install pandas

# %%
import pandas

# %%
pandas.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
DataFrame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 DataFrame()
#
# NameError: name 'DataFrame' is not defined

# %%
import pandas as pd #Alias
import numpy as np

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Pandas DataFrame

# %% [markdown]
# # Loading external csv files

# %%
pd.read_csv(r"C:\Users\suruk\OneDrive\Desktop\cars.csv")
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                150  alfa-romero       gas
# 1             1          3                150  alfa-romero       gas
# 2             2          1                150  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1                 95        volvo       gas
# 201         201         -1                 95        volvo       gas
# 202         202         -1                 95        volvo       gas
# 203         203         -1                 95        volvo    diesel
# 204         204         -1                 95        volvo       gas
#
#       body-style drive-wheels engine-location  width  height engine-type  \
# ...

# %%
df = pd.read_csv(r"C:\Users\suruk\OneDrive\Desktop\cars.csv")
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                150  alfa-romero       gas
# 1             1          3                150  alfa-romero       gas
# 2             2          1                150  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1                 95        volvo       gas
# 201         201         -1                 95        volvo       gas
# 202         202         -1                 95        volvo       gas
# 203         203         -1                 95        volvo    diesel
# 204         204         -1                 95        volvo       gas
#
#       body-style drive-wheels engine-location  width  height engine-type  \
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True) #REMOVE COLUMNS

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                150  alfa-romero       gas  convertible
# 1            3                150  alfa-romero       gas  convertible
# 2            1                150  alfa-romero       gas    hatchback
# 3            2                164         audi       gas        sedan
# 4            2                164         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                 95        volvo       gas        sedan
# 201         -1                 95        volvo       gas        sedan
# 202         -1                 95        volvo       gas        sedan
# 203         -1                 95        volvo    diesel        sedan
# 204         -1                 95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.head(10)
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3                150  alfa-romero       gas  convertible
# 1          3                150  alfa-romero       gas  convertible
# 2          1                150  alfa-romero       gas    hatchback
# 3          2                164         audi       gas        sedan
# 4          2                164         audi       gas        sedan
# 5          2                150         audi       gas        sedan
# 6          1                158         audi       gas        sedan
# 7          1                150         audi       gas        wagon
# 8          1                158         audi       gas        sedan
# 9          0                150         audi       gas    hatchback
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# ...

# %%
df.tail(2)
# Out:
#      symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 203         -1                 95  volvo    diesel      sedan          rwd
# 204         -1                 95  volvo       gas      sedan          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 203           front   68.9    55.5         ohc          145         106
# 204           front   68.9    55.5         ohc          141         114
#
#      city-mpg  highway-mpg  price
# 203        26           27  22470
# 204        19           25  22625

# %%
#Describing the dataset

# %%
df.describe()
# Out:
#         symboling  normalized-losses       width      height  engine-size  \
# count  205.000000         205.000000  205.000000  205.000000   205.000000
# mean     0.834146         127.600000   65.907805   53.724878   126.907317
# std      1.245307          33.611623    2.145204    2.443522    41.642693
# min     -2.000000          65.000000   60.300000   47.800000    61.000000
# 25%      0.000000         101.000000   64.100000   52.000000    97.000000
# 50%      1.000000         128.000000   65.500000   54.100000   120.000000
# 75%      2.000000         150.000000   66.900000   55.500000   141.000000
# max      3.000000         256.000000   72.300000   59.800000   326.000000
#
#        horsepower    city-mpg  highway-mpg         price
# count  205.000000  205.000000   205.000000    205.000000
# mean   104.702439   25.219512    30.751220  13227.478049
# std     39.775402    6.542142     6.886443   7902.651615
# min     48.000000   13.000000    16.000000   5118.000000
# ...

# %%
df['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: int64

# %%
df['price'].sum()
# Out:
# 2711633

# %%
df[["make","price"]]
# Out:
#             make  price
# 0    alfa-romero  13495
# 1    alfa-romero  16500
# 2    alfa-romero  16500
# 3           audi  13950
# 4           audi  17450
# ..           ...    ...
# 200        volvo  16845
# 201        volvo  19045
# 202        volvo  21485
# 203        volvo  22470
# 204        volvo  22625
#
# [205 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'body-style',
#        'drive-wheels', 'engine-location', 'width', 'height', 'engine-type',
#        'engine-size', 'horsepower', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
#Extracting columns from dataset
df.head(10)

# %%
#loc and #iloc -- Extracting records

# %%
#loc -- stands for location

# %%
df.head()

# %%
#Extract records from row 5 to 25 from first 3 cols

df.loc[5:25,'symboling':'make']

# %%
df.iloc[5:25,0:3]

# %%
#Basic functions of pandas library

# %%
df.info()

# %%
#Checking unique values from columns

# %%
df.head()

# %%
df['body-style']

# %%
df['body-style'].unique()

# %%
df['make'].unique()

# %%
df['make'].nunique()   #Number of unique values in a column

# %%
df['body-style'].nunique()

# %%
df['body-style'].value_counts()

# %%
df['make'].value_counts()

# %%
df['fuel-type'].value_counts()

# %%
df

# %% [markdown]
# # Pandas filtering

# %%
df = pd.read_csv("Salaries.csv")
df

# %%
df['rank'].unique()

# %%
#Extract records where rank = AsstProf (Conditions)

# %%
df['rank']

# %%
df['rank'] == 'AsstProf'

# %%
df[df['rank'] == 'AsstProf'] #--> Masking

# %%
len(df[df['rank'] == 'AsstProf'])

# %%
df['salary'] > 92000

# %%
df[df['salary'] > 92000]

# %%
#Extract records where gender = Male and salary > 100000

# %%
df[(df['gender'] == 'Male') & (df['salary'] > 100000)]

# %%
df[(df['gender']=='Male') | (df['salary'] > 100000)]b

# %%
df[(df['rank'] == 'Prof') & (df['discipline'] == 'A') & (df['gender'] == 'Female')]

# %%
df['rank'].unique()

# %%
df['rank'].value_counts()

# %%
df

# %%
df['salary'].mean()

# %%
df[df['rank'] == 'Prof']

# %%
df[df['rank'] == 'Prof']['salary'].mean()

# %%
df[df['rank'] == 'Prof']['salary'].min()

# %%
df[df['rank'] == 'Prof']['salary'].max()

# %%
print(df[df['rank'] == 'Prof']['salary'].mean())
print(df[df['rank'] == 'AsstProf']['salary'].mean())
print(df[df['rank'] == 'AssocProf']['salary'].mean())

# %% [markdown]
# # Group by

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.groupby('Position')

# %%
df.groupby('Position')['Salary'].mean()
# Out:
# Position
# C     5.967052e+06
# PF    4.562483e+06
# PG    5.077829e+06
# SF    4.857393e+06
# SG    4.009861e+06
# Name: Salary, dtype: float64

# %%
df.groupby('rank')['salary'].agg({'min','max','mean','median'})

# %% [markdown]
# # Home - work

# %% [markdown]
# 1. Extract records where team = boston celtics and weight > 190
# 2. Which player goes to California college
# 3. Calculate average salary of players based on Positions that they belong to.
# 4. Avearge salary of players of Chicago Bulls Team
# 5. Calculate (mean, median, min, max) salary of players based on Team.

# %%
df = pd.read_csv(r"C:\Users\suruk\OneDrive\Desktop\basic statistics\nba.csv")
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df[(df['Team']=='Boston Celtics') & (df['Weight']>190)]
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 12      Evan Turner  Boston Celtics    11.0       SG  27.0    6-7   220.0
# 13      James Young  Boston Celtics    13.0       SG  20.0    6-6   215.0
# 14     Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0   253.0
#
#               College      Salary
# 1           Marquette   6796117.0
# ...

# %%
df.loc[df["College"]=='California','Name']
# Out:
# 276      Ryan Anderson
# 326    Jorge Gutierrez
# 430       Allen Crabbe
# Name: Name, dtype: object

# %%
df[df["College"]=='California']
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 276    Ryan Anderson    New Orleans Pelicans    33.0       PF  28.0   6-10
# 326  Jorge Gutierrez       Charlotte Hornets    12.0       PG  27.0    6-3
# 430     Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0    6-6
#
#      Weight     College     Salary
# 276   240.0  California  8500000.0
# 326   189.0  California   189455.0
# 430   210.0  California   947276.0

# %%
df.groupby('Position')['Salary'].mean()
# Out:
# Position
# C     5.967052e+06
# PF    4.562483e+06
# PG    5.077829e+06
# SF    4.857393e+06
# SG    4.009861e+06
# Name: Salary, dtype: float64

# %%
df.groupby(df['Team']=='Chicago Bulls')['Salary'].mean()
# Out:
# Team
# False    4.809869e+06
# True     5.785559e+06
# Name: Salary, dtype: float64

# %%
df.groupby('Team')['Salary'].agg({'min','max','mean','median'})
# Out:
#                               min     median          mean         max
# Team
# Atlanta Hawks            525093.0  2854940.0  4.860197e+06  18671659.0
# Boston Celtics          1148640.0  3021242.5  4.181505e+06  12000000.0
# Brooklyn Nets            134215.0  1335480.0  3.501898e+06  19689000.0
# Charlotte Hornets        189455.0  4204200.0  5.222728e+06  13500000.0
# Chicago Bulls            525093.0  2380440.0  5.785559e+06  20093064.0
# Cleveland Cavaliers      111196.0  4975000.0  7.642049e+06  22970500.0
# Dallas Mavericks         525093.0  3950313.0  4.746582e+06  16407500.0
# Denver Nuggets           258489.0  2907000.0  4.294424e+06  14000000.0
# Detroit Pistons          111444.0  2891760.0  4.477884e+06  16000000.0
# Golden State Warriors    289755.0  3815000.0  5.924600e+06  15501000.0
# Houston Rockets          200600.0  2288205.0  5.018868e+06  22359364.0
# Indiana Pacers           211744.0  4000000.0  4.450122e+06  17120106.0
# ...

# %%
df=pd.read_excel(r"C:\Users\suruk\Downloads\fact_bookings..xlsx")

# %%
df
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2022-04-27    2022-05-01
# 1        May012216558RT12        16558   2022-04-30    2022-05-01
# 2        May012216558RT13        16558   2022-04-28    2022-05-01
# 3        May012216558RT14        16558   2022-04-28    2022-05-01
# 4        May012216558RT15        16558   2022-04-27    2022-05-01
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47        17564   2022-07-30    2022-07-31
# 134587   Jul312217564RT48        17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49        17564   2022-07-29    2022-07-31
# 134589  Jul312217564RT410        17564   2022-07-31    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         2022-05-02          3           RT1    direct online            1.0
# ...

# %%
df=pd.read_csv('weather_data (1).csv',parse_dates=["day"])
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.isnull().sum()
# Out:
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
#filling null values
new_df=df.fillna('0') # filling with zero
new_df
# Out:
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0    Rain
# 2017-01-04           0       9.0   Sunny
# 2017-01-05        28.0         0    Snow
# 2017-01-06           0       7.0       0
# 2017-01-07        32.0         0    Rain
# 2017-01-08           0         0   Sunny
# 2017-01-09           0         0       0
# 2017-01-10        34.0       8.0  Cloudy
# 2017-01-11        40.0      12.0   Sunny

# %%
new_df=df.fillna({'temperature':0.0,'windspeed':0.0,'event':'No event'})
new_df # filling column wise
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  No event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  No event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
new_df=df.ffill() # fills null values with it's before days
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.interpolate() #changes null numerical values based on linear relation
new_df
# Out:
# C:\Users\suruk\AppData\Local\Temp\ipykernel_20680\1725489846.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df=df.interpolate()
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(how="all") #removes only all the rows which null values
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=1) #removes 1 row which haves all null values
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.replace(32.0,np.NaN)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01          NaN        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07          NaN        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df=pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df=pd.concat([india_weather,us_weather],keys=["india","us"])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc["india"]
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
#conatenating using index
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#      city  windspeed
# 1   delhi          7
# 0  mumbai         12

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN
